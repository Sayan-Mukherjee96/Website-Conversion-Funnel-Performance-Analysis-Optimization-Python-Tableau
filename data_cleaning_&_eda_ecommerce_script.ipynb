# %% [markdown]
# # <LEFT>EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:/Tableau/Project/website_sessions.csv")

# %%
session = data.copy()

# %%
session.head(15)
# Out:
#      website_session_id           created_at  user_id  is_repeat_session  \
# 0                     1  2012-03-19 08:04:16        1                  0
# 1                     2  2012-03-19 08:16:49        2                  0
# 2                     3  2012-03-19 08:26:55        3                  0
# 3                     4  2012-03-19 08:37:33        4                  0
# 4                     5  2012-03-19 09:00:55        5                  0
# ..                  ...                  ...      ...                ...
# 510                 511  2012-03-22 07:14:05      511                  0
# 511                 512  2012-03-22 07:17:59      512                  0
# 512                 513  2012-03-22 07:18:42      513                  0
# 513                 514  2012-03-22 07:25:26      514                  0
# 514                 515  2012-03-22 07:32:44      515                  0
#
#     utm_source utm_campaign utm_content device_type             http_referer
# ...

# %%
session.tail()
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 472866              472867  2015-03-19 07:49:25   394314                  0
# 472867              472868  2015-03-19 07:54:36   394315                  0
# 472868              472869  2015-03-19 07:55:40   394316                  0
# 472869              472870  2015-03-19 07:56:29   394317                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
#        utm_source utm_campaign utm_content device_type  \
# 472866    gsearch        brand      g_ad_2     desktop
# 472867    bsearch     nonbrand      b_ad_1      mobile
# 472868    gsearch     nonbrand      g_ad_1      mobile
# 472869    gsearch     nonbrand      g_ad_1     desktop
# 472870        NaN          NaN         NaN      mobile
#
#                    http_referer
# 472866  https://www.gsearch.com
# 472867  https://www.bsearch.com
# 472868  https://www.gsearch.com
# 472869  https://www.gsearch.com
# ...

# %%
session['utm_source'].mode()
# Out:
# 0    gsearch
# Name: utm_source, dtype: object

# %%
session['utm_campaign'].mode()
# Out:
# 0    nonbrand
# Name: utm_campaign, dtype: object

# %%
session['utm_content'].mode()
# Out:
# 0    g_ad_1
# Name: utm_content, dtype: object

# %%
session['http_referer'].mode()
# Out:
# 0    https://www.gsearch.com
# Name: http_referer, dtype: object

# %%
session['http_referer'].isnull()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 472866    False
# 472867    False
# 472868    False
# 472869    False
# 472870     True
# Name: http_referer, Length: 472871, dtype: bool

# %%
session[session['utm_source'].isna()]
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 904                    905  2012-03-25 07:24:18      905                  0
# 914                    915  2012-03-25 10:45:03      915                  0
# 933                    934  2012-03-25 14:23:48      934                  0
# 1044                  1045  2012-03-26 11:54:49      846                  1
# 1050                  1051  2012-03-26 12:48:41      152                  1
# ...                    ...                  ...      ...                ...
# 472835              472836  2015-03-19 06:25:38   394289                  0
# 472846              472847  2015-03-19 06:57:13   378178                  1
# 472860              472861  2015-03-19 07:38:28   383375                  1
# 472863              472864  2015-03-19 07:41:11   394311                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
# ...

# %%
session.fillna(method='ffill', inplace = True)
# Out:
# C:\Users\sayan mukherjee\AppData\Local\Temp\ipykernel_11380\3290390210.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   session.fillna(method='ffill', inplace = True)

# %%
session
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 0                        1  2012-03-19 08:04:16        1                  0
# 1                        2  2012-03-19 08:16:49        2                  0
# 2                        3  2012-03-19 08:26:55        3                  0
# 3                        4  2012-03-19 08:37:33        4                  0
# 4                        5  2012-03-19 09:00:55        5                  0
# ...                    ...                  ...      ...                ...
# 472866              472867  2015-03-19 07:49:25   394314                  0
# 472867              472868  2015-03-19 07:54:36   394315                  0
# 472868              472869  2015-03-19 07:55:40   394316                  0
# 472869              472870  2015-03-19 07:56:29   394317                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
# ...

# %%
session.to_csv("D:/Tableau/Project/website_session_clean.csv", index=False)

# %%
order = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/orders.csv")

# %%
order
# Out:
#        order_id           created_at  website_session_id  user_id  \
# 0             1  2012-03-19 10:42:46                  20       20
# 1             2  2012-03-19 19:27:37                 104      104
# 2             3  2012-03-20 06:44:45                 147      147
# 3             4  2012-03-20 09:41:45                 160      160
# 4             5  2012-03-20 11:28:15                 177      177
# ...         ...                  ...                 ...      ...
# 32308     32309  2015-03-19 03:58:12              472795   394255
# 32309     32310  2015-03-19 04:10:43              472798   394257
# 32310     32311  2015-03-19 05:27:28              472809   394268
# 32311     32312  2015-03-19 05:35:57              472814   394273
# 32312     32313  2015-03-19 05:38:31              472818   386000
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 0                       1                1      49.99     19.49
# ...

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32313 entries, 0 to 32312
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            32313 non-null  int64
#  1   created_at          32313 non-null  object
#  2   website_session_id  32313 non-null  int64
#  3   user_id             32313 non-null  int64
#  4   primary_product_id  32313 non-null  int64
#  5   items_purchased     32313 non-null  int64
#  6   price_usd           32313 non-null  float64
#  7   cogs_usd            32313 non-null  float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.0+ MB

# %%
order.describe()
# Out:
#            order_id  website_session_id        user_id  primary_product_id  \
# count  32313.000000        32313.000000   32313.000000        32313.000000
# mean   16157.000000       258292.288707  215691.622629            1.392474
# std     9328.103961       132427.649842  108402.203189            0.732277
# min        1.000000           20.000000      13.000000            1.000000
# 25%     8079.000000       144828.000000  124135.000000            1.000000
# 50%    16157.000000       263554.000000  221461.000000            1.000000
# 75%    24235.000000       374799.000000  310542.000000            2.000000
# max    32313.000000       472818.000000  394273.000000            4.000000
#
#        items_purchased     price_usd      cogs_usd
# count     32313.000000  32313.000000  32313.000000
# mean          1.238666     59.991636     22.355406
# std           0.426274     17.808771      6.238621
# min           1.000000     29.990000      9.490000
# ...

# %%
order_item_refund = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/order_item_refunds.csv")

# %%
order_item_refund
# Out:
#       order_item_refund_id           created_at  order_item_id  order_id  \
# 0                        1  2012-04-06 11:32:43             57        57
# 1                        2  2012-04-13 01:09:43             74        74
# 2                        3  2012-04-15 07:03:48             71        71
# 3                        4  2012-04-17 20:00:37            118       118
# 4                        5  2012-04-22 20:53:49            116       116
# ...                    ...                  ...            ...       ...
# 1726                  1727  2015-03-30 09:37:23          39950     32255
# 1727                  1728  2015-03-30 21:33:51          39671     32049
# 1728                  1729  2015-03-31 19:59:48          39729     32090
# 1729                  1730  2015-04-01 03:54:48          39717     32079
# 1730                  1731  2015-04-01 18:11:08          39947     32252
#
#       refund_amount_usd
# 0                 49.99
# 1                 49.99
# ...

# %%
order_item_refund.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1731 entries, 0 to 1730
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   order_item_refund_id  1731 non-null   int64
#  1   created_at            1731 non-null   object
#  2   order_item_id         1731 non-null   int64
#  3   order_id              1731 non-null   int64
#  4   refund_amount_usd     1731 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 67.7+ KB

# %%
order_item_refund.describe()
# Out:
#        order_item_refund_id  order_item_id      order_id  refund_amount_usd
# count           1731.000000    1731.000000   1731.000000        1731.000000
# mean             866.000000   18472.214905  15868.242057          49.300225
# std              499.840975   11438.074606   9096.061945           4.956015
# min                1.000000      57.000000     57.000000          29.990000
# 25%              433.500000    7417.000000   7412.000000          49.990000
# 50%              866.000000   19858.000000  17375.000000          49.990000
# 75%             1298.500000   26900.000000  22539.500000          49.990000
# max             1731.000000   39950.000000  32255.000000          59.990000

# %%
order_item = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/order_items.csv")

# %%
order_item
# Out:
#        order_item_id           created_at  order_id  product_id  \
# 0                  1  2012-03-19 10:42:46         1           1
# 1                  2  2012-03-19 19:27:37         2           1
# 2                  3  2012-03-20 06:44:45         3           1
# 3                  4  2012-03-20 09:41:45         4           1
# 4                  5  2012-03-20 11:28:15         5           1
# ...              ...                  ...       ...         ...
# 40020          40021  2015-03-19 04:10:43     32310           4
# 40021          40022  2015-03-19 05:27:28     32311           2
# 40022          40023  2015-03-19 05:27:28     32311           4
# 40023          40024  2015-03-19 05:35:57     32312           4
# 40024          40025  2015-03-19 05:38:31     32313           1
#
#        is_primary_item  price_usd  cogs_usd
# 0                    1      49.99     19.49
# 1                    1      49.99     19.49
# 2                    1      49.99     19.49
# ...

# %%
order_item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40025 entries, 0 to 40024
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   order_item_id    40025 non-null  int64
#  1   created_at       40025 non-null  object
#  2   order_id         40025 non-null  int64
#  3   product_id       40025 non-null  int64
#  4   is_primary_item  40025 non-null  int64
#  5   price_usd        40025 non-null  float64
#  6   cogs_usd         40025 non-null  float64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 2.1+ MB

# %%
order_item.describe()
# Out:
#        order_item_id      order_id    product_id  is_primary_item  \
# count   40025.000000  40025.000000  40025.000000     40025.000000
# mean    20013.000000  17121.957502      1.770019         0.807320
# std     11554.366599   9053.765867      1.085561         0.394408
# min         1.000000      1.000000      1.000000         0.000000
# 25%     10007.000000   9871.000000      1.000000         1.000000
# 50%     20013.000000  17490.000000      1.000000         1.000000
# 75%     30019.000000  24818.000000      2.000000         1.000000
# max     40025.000000  32313.000000      4.000000         1.000000
#
#           price_usd      cogs_usd
# count  40025.000000  40025.000000
# mean      48.432473     18.047976
# std        8.012370      3.856821
# min       29.990000      9.490000
# 25%       49.990000     19.490000
# 50%       49.990000     19.490000
# 75%       49.990000     19.490000
# max       59.990000     22.490000

# %%
order = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/orders.csv")

# %%
order
# Out:
#        order_id           created_at  website_session_id  user_id  \
# 0             1  2012-03-19 10:42:46                  20       20
# 1             2  2012-03-19 19:27:37                 104      104
# 2             3  2012-03-20 06:44:45                 147      147
# 3             4  2012-03-20 09:41:45                 160      160
# 4             5  2012-03-20 11:28:15                 177      177
# ...         ...                  ...                 ...      ...
# 32308     32309  2015-03-19 03:58:12              472795   394255
# 32309     32310  2015-03-19 04:10:43              472798   394257
# 32310     32311  2015-03-19 05:27:28              472809   394268
# 32311     32312  2015-03-19 05:35:57              472814   394273
# 32312     32313  2015-03-19 05:38:31              472818   386000
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 0                       1                1      49.99     19.49
# ...

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32313 entries, 0 to 32312
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            32313 non-null  int64
#  1   created_at          32313 non-null  object
#  2   website_session_id  32313 non-null  int64
#  3   user_id             32313 non-null  int64
#  4   primary_product_id  32313 non-null  int64
#  5   items_purchased     32313 non-null  int64
#  6   price_usd           32313 non-null  float64
#  7   cogs_usd            32313 non-null  float64
# dtypes: float64(2), int64(5), object(1)
# memory usage: 2.0+ MB

# %%
order.describe()
# Out:
#            order_id  website_session_id        user_id  primary_product_id  \
# count  32313.000000        32313.000000   32313.000000        32313.000000
# mean   16157.000000       258292.288707  215691.622629            1.392474
# std     9328.103961       132427.649842  108402.203189            0.732277
# min        1.000000           20.000000      13.000000            1.000000
# 25%     8079.000000       144828.000000  124135.000000            1.000000
# 50%    16157.000000       263554.000000  221461.000000            1.000000
# 75%    24235.000000       374799.000000  310542.000000            2.000000
# max    32313.000000       472818.000000  394273.000000            4.000000
#
#        items_purchased     price_usd      cogs_usd
# count     32313.000000  32313.000000  32313.000000
# mean          1.238666     59.991636     22.355406
# std           0.426274     17.808771      6.238621
# min           1.000000     29.990000      9.490000
# ...

# %%
product = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/products.csv")

# %%
product
# Out:
#    product_id           created_at                product_name
# 0           1  2012-03-19 08:00:00      The Original Mr. Fuzzy
# 1           2  2013-01-06 13:00:00       The Forever Love Bear
# 2           3  2013-12-12 09:00:00    The Birthday Sugar Panda
# 3           4  2014-02-05 10:00:00  The Hudson River Mini bear

# %%
website_pageview = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/website_pageviews.csv")

# %%
website_pageview
# Out:
#          website_pageview_id           created_at  website_session_id  \
# 0                          1  2012-03-19 08:04:16                   1
# 1                          2  2012-03-19 08:16:49                   2
# 2                          3  2012-03-19 08:26:55                   3
# 3                          4  2012-03-19 08:37:33                   4
# 4                          5  2012-03-19 09:00:55                   5
# ...                      ...                  ...                 ...
# 1188119              1188120  2015-03-19 07:57:32              472866
# 1188120              1188121  2015-03-19 07:58:13              472870
# 1188121              1188122  2015-03-19 07:59:07              472866
# 1188122              1188123  2015-03-19 07:59:08              472871
# 1188123              1188124  2015-03-19 07:59:32              472868
#
#                    pageview_url
# 0                         /home
# 1                         /home
# ...

# %%
website_pageview.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1188124 entries, 0 to 1188123
# Data columns (total 4 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   website_pageview_id  1188124 non-null  int64
#  1   created_at           1188124 non-null  object
#  2   website_session_id   1188124 non-null  int64
#  3   pageview_url         1188124 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 36.3+ MB

# %%
website_session = pd.read_csv(r"D:/Tableau/Project/Maven+Fuzzy+Factory/website_session_clean.csv")

# %%
website_session
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 0                        1  2012-03-19 08:04:16        1                  0
# 1                        2  2012-03-19 08:16:49        2                  0
# 2                        3  2012-03-19 08:26:55        3                  0
# 3                        4  2012-03-19 08:37:33        4                  0
# 4                        5  2012-03-19 09:00:55        5                  0
# ...                    ...                  ...      ...                ...
# 472866              472867  2015-03-19 07:49:25   394314                  0
# 472867              472868  2015-03-19 07:54:36   394315                  0
# 472868              472869  2015-03-19 07:55:40   394316                  0
# 472869              472870  2015-03-19 07:56:29   394317                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
# ...

# %%
website_session.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 472871 entries, 0 to 472870
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   website_session_id  472871 non-null  int64
#  1   created_at          472871 non-null  object
#  2   user_id             472871 non-null  int64
#  3   is_repeat_session   472871 non-null  int64
#  4   utm_source          472871 non-null  object
#  5   utm_campaign        472871 non-null  object
#  6   utm_content         472871 non-null  object
#  7   device_type         472871 non-null  object
#  8   http_referer        472871 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 32.5+ MB

# %%
website_session.describe()
# Out:
#        website_session_id        user_id  is_repeat_session
# count       472871.000000  472871.000000      472871.000000
# mean        236436.000000  198037.970163           0.166119
# std         136506.243908  111992.997798           0.372188
# min              1.000000       1.000000           0.000000
# 25%         118218.500000  101966.500000           0.000000
# 50%         236436.000000  199483.000000           0.000000
# 75%         354653.500000  294433.000000           0.000000
# max         472871.000000  394318.000000           1.000000

# %%
website_session
# Out:
#         website_session_id           created_at  user_id  is_repeat_session  \
# 0                        1  2012-03-19 08:04:16        1                  0
# 1                        2  2012-03-19 08:16:49        2                  0
# 2                        3  2012-03-19 08:26:55        3                  0
# 3                        4  2012-03-19 08:37:33        4                  0
# 4                        5  2012-03-19 09:00:55        5                  0
# ...                    ...                  ...      ...                ...
# 472866              472867  2015-03-19 07:49:25   394314                  0
# 472867              472868  2015-03-19 07:54:36   394315                  0
# 472868              472869  2015-03-19 07:55:40   394316                  0
# 472869              472870  2015-03-19 07:56:29   394317                  0
# 472870              472871  2015-03-19 07:59:08   394318                  0
#
# ...

# %%
order
# Out:
#        order_id           created_at  website_session_id  user_id  \
# 0             1  2012-03-19 10:42:46                  20       20
# 1             2  2012-03-19 19:27:37                 104      104
# 2             3  2012-03-20 06:44:45                 147      147
# 3             4  2012-03-20 09:41:45                 160      160
# 4             5  2012-03-20 11:28:15                 177      177
# ...         ...                  ...                 ...      ...
# 32308     32309  2015-03-19 03:58:12              472795   394255
# 32309     32310  2015-03-19 04:10:43              472798   394257
# 32310     32311  2015-03-19 05:27:28              472809   394268
# 32311     32312  2015-03-19 05:35:57              472814   394273
# 32312     32313  2015-03-19 05:38:31              472818   386000
#
#        primary_product_id  items_purchased  price_usd  cogs_usd
# 0                       1                1      49.99     19.49
# ...

# %%
plt.figure(figsize=(8,8))

plt.title("No. of Session By Utm Source")
counts = website_session["utm_source"].value_counts()

plt.bar(counts.index, counts.values)

plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.title("No. of Session by Device Type")

counts = website_session["device_type"].value_counts()

plt.bar(counts.index, counts.values)

plt.xticks(rotation=45)
plt.show()

# %%
order.rename(columns={"price_usd": "revenue"}, inplace=True)

# %%
order
# Out:
#        order_id           created_at  website_session_id  user_id  \
# 0             1  2012-03-19 10:42:46                  20       20
# 1             2  2012-03-19 19:27:37                 104      104
# 2             3  2012-03-20 06:44:45                 147      147
# 3             4  2012-03-20 09:41:45                 160      160
# 4             5  2012-03-20 11:28:15                 177      177
# ...         ...                  ...                 ...      ...
# 32308     32309  2015-03-19 03:58:12              472795   394255
# 32309     32310  2015-03-19 04:10:43              472798   394257
# 32310     32311  2015-03-19 05:27:28              472809   394268
# 32311     32312  2015-03-19 05:35:57              472814   394273
# 32312     32313  2015-03-19 05:38:31              472818   386000
#
#        primary_product_id  items_purchased  revenue  cogs_usd
# 0                       1                1    49.99     19.49
# ...

# %%
merged_df = pd.merge(order, website_session,
                     on="website_session_id",
                     how="left")

# %%
plt.figure(figsize=(8,6))

sns.barplot(
    data=merged_df,
    x="device_type",
    y="revenue",
    estimator=np.sum
)

plt.title("Total Revenue by Device Type")
plt.xlabel("Device Type")
plt.ylabel("Total Revenue")
plt.show()

# %%
plt.figure(figsize=(8,6))

sns.barplot(
    data=merged_df,
    x="utm_source",
    y="revenue",
    estimator=np.sum
)

plt.title("Total Revenue by Utm Source")
plt.xlabel("Utm Source")
plt.ylabel("Total Revenue")
plt.show()

# %%
order["created_at"] = pd.to_datetime(order["created_at"])

order["date"] = order["created_at"].dt.year

yearly_revenue = order.groupby("date")["revenue"].mean().reset_index()

plt.figure(figsize=(12,8))

sns.lineplot(
    data=yearly_revenue,
    x="date",
    y="revenue"
)

plt.title("Yearly Average Revenue")
plt.xlabel("Date")
plt.ylabel("Average Revenue")

plt.xticks(rotation=45)
plt.show()

# %%
website_session["created_at"] = pd.to_datetime(order["created_at"])

website_session["date"] = website_session["created_at"].dt.year

yearly_session = website_session.groupby("date")["website_session_id"].count().reset_index()

plt.figure(figsize=(12,8))

sns.lineplot(
    data=yearly_session,
    x="date",
    y="website_session_id"
)

plt.title("Yearly Total Session")
plt.xlabel("Date")
plt.ylabel("No. of Session")

plt.xticks(rotation=45)
plt.show()

# %%
order["created_at"] = pd.to_datetime(order["created_at"])

order["year"] = order["created_at"].dt.year  

yearly_order = order.groupby("year")["items_purchased"].mean().reset_index()

plt.figure(figsize=(12,8))

sns.lineplot(
    data=yearly_order,
    x="year",
    y="items_purchased"
)

plt.title("Yearly Average Items Purchased")
plt.xlabel("Year")
plt.ylabel("Average Items Purchased")

plt.xticks(rotation=45)
plt.show()
